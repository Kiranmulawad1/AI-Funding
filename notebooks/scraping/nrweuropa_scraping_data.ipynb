# %%
# !pip install playwright beautifulsoup4 pandas nest_asyncio
# !playwright install
# Out:
# Requirement already satisfied: playwright in /Users/kiranmulawad/AI-Funding/.env/lib/python3.12/site-packages (1.52.0)
# Requirement already satisfied: beautifulsoup4 in /Users/kiranmulawad/AI-Funding/.env/lib/python3.12/site-packages (4.13.4)
# Requirement already satisfied: pandas in /Users/kiranmulawad/AI-Funding/.env/lib/python3.12/site-packages (2.3.0)
# Requirement already satisfied: nest_asyncio in /Users/kiranmulawad/AI-Funding/.env/lib/python3.12/site-packages (1.6.0)
# Requirement already satisfied: pyee<14,>=13 in /Users/kiranmulawad/AI-Funding/.env/lib/python3.12/site-packages (from playwright) (13.0.0)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /Users/kiranmulawad/AI-Funding/.env/lib/python3.12/site-packages (from playwright) (3.2.3)
# Requirement already satisfied: typing-extensions in /Users/kiranmulawad/AI-Funding/.env/lib/python3.12/site-packages (from pyee<14,>=13->playwright) (4.13.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/kiranmulawad/AI-Funding/.env/lib/python3.12/site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: numpy>=1.26.0 in /Users/kiranmulawad/AI-Funding/.env/lib/python3.12/site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/kiranmulawad/AI-Funding/.env/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/kiranmulawad/AI-Funding/.env/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/kiranmulawad/AI-Funding/.env/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/kiranmulawad/AI-Funding/.env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import asyncio
from playwright.async_api import async_playwright
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
async def scrape_nrweuropa():
    url = "https://nrweuropa.de/cascadefunding/"
    funding_data = []

    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()
        try:
            await page.goto(url, timeout=60000)
            html = await page.content()
        except Exception as e:
            print(f"Error loading page: {e}")
            await browser.close()
            return pd.DataFrame()
        await browser.close()

    soup = BeautifulSoup(html, "html.parser")
    strong_tags = soup.find_all("strong", string=lambda text: text and "Open Call" in text)

    for tag in strong_tags:
        try:
            title = tag.get_text(strip=True)
            parent_p = tag.find_parent("p")
            if not parent_p:
                continue

            # Combine paragraph + nearby text
            full_text = parent_p.get_text(" ", strip=True)
            for i, sibling in enumerate(parent_p.next_siblings):
                if i >= 5: break
                if hasattr(sibling, "get_text"):
                    full_text += " " + sibling.get_text(" ", strip=True)

            # Extract fields using regex
            extract = lambda pattern: re.search(pattern, full_text)
            topic = extract(r"Thema:\s*(.*?)\s*(Förderfähig:|Budget:|Antragsfrist:|$)")
            eligibility = extract(r"Förderfähig:\s*(.*?)\s*(Budget:|Antragsfrist:|$)")
            budget = extract(r"Budget:\s*(.*?)\s*(Antragsfrist:|$)")
            deadline = extract(r"Antragsfrist:\s*([\d\.]+\s+[A-Za-zäöüÄÖÜ]+\s+\d{4})")

            topic = topic.group(1).strip() if topic else None
            eligibility = eligibility.group(1).strip() if eligibility else None
            budget = budget.group(1).strip() if budget else None
            deadline = deadline.group(1).strip() if deadline else None

            # Clean Description
            description = full_text
            for label, val in {
                "Thema:": topic,
                "Förderfähig:": eligibility,
                "Budget:": budget,
                "Antragsfrist:": deadline,
                title: title
            }.items():
                if val:
                    description = description.replace(f"{label} {val}", "")
            description = description.replace(title, "").strip()

            # Extract URL
            url_link = next(
                (a.get("href") for a in parent_p.find_all("a") if a.get("href")),
                None
            )
            if not url_link:
                for i, sibling in enumerate(parent_p.next_siblings):
                    if i >= 5: break
                    if hasattr(sibling, "find"):
                        a = sibling.find("a")
                        if hasattr(a, "get"):
                            href = a.get("href")
                            if href and href.strip():
                                url_link = href
                                break

            funding_data.append({
                "Name": title,
                "Topic": topic,
                "Eligibility": eligibility,
                "Budget": budget,
                "Deadline": deadline,
                "Description": description,
                "URL": url_link,
            })
        except Exception as e:
            print(f"Error parsing entry: {e}")

    return pd.DataFrame(funding_data)

# %%
df = asyncio.run(scrape_nrweuropa())
df.head()
# Out:
#                       Name                                              Topic  \
# 0     FORTIS 1st Open Call  Mensch-Roboter-Interaktion (HRI), multimodale ...
# 1     MASTER 2nd Open Call                                              VR/XR
# 2    PEDVolution Open Call                     Energienetze, Energieeffizienz
# 3      SMURF 2nd Open Call                 Fortswirtschaft & Waldbewirtschaft
# 4  GUARDIANS 1st Open Call                   Landwirtschaft & Digitalisierung
#
#                                          Eligibility               Budget  \
# 0  Konsortien aus 2-3 Organisationen: Start-ups, ...  Bis zu 250.000 Euro
# 1  Universitäten, Forschungseinrichtungen, Bildun...  Bis zu 100.000 Euro
# 2  Start-ups, KMU, Mid-caps, Forschungseinrichtun...   Bis zu 50.000 Euro
# 3  Kommunen, Verbände, Föderationen, oder Genosse...   Bis zu 60.000 Euro
# 4  KMU, Start-Up, Forschungseinrichtung oder Univ...   Bis zu 81.000 Euro
#
#         Deadline                                        Description  \
# 0   4. Juni 2025  FORTIS unterstützt Projekte, die innovative Lö...
# 1  12. Juni 2025  MASTER unterstützt Projekte, die innovative XR...
# 2  30. Juni 2025  PEDvolution unterstützt Projekte, die innovati...
# 3   2. Juli 2025  Das SMURF-Projekt zielt darauf ab, Innovation,...
# 4  15. Juli 2025  GUARDIANS fördert die gemeinsame Entwicklung, ...
#
#                                                  URL
# 0             https://fortis-project.eu/open-call-1/
# 1   https://www.master-xr.eu/open-calls/open-call-2/
# 2  https://news.pedvolution.eu/posts/open-call-fo...
# 3  https://www.smurfproject.eu/cascade-funding-sm...
# 4  https://guardians-project.eu/call/open-call-1-...

# %%
df.to_csv("funding_nrweuropa_data.csv", index=False)
print("✅ Data saved to funding_nrweuropa_data.csv")
# Out:
# ✅ Data saved to funding_nrweuropa_data.csv
