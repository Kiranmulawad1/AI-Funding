# %%
import sys
# !{sys.executable} -m pip uninstall -y pinecone-client
# Out:
# Found existing installation: pinecone-client 2.2.4
# Uninstalling pinecone-client-2.2.4:
#   Successfully uninstalled pinecone-client-2.2.4

# %%
# !{sys.executable} -m pip install "pinecone-client<3.0.0"
# Out:
# Collecting pinecone-client<3.0.0
#   Using cached pinecone_client-2.2.4-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: requests>=2.19.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone-client<3.0.0) (2.32.4)
# Requirement already satisfied: pyyaml>=5.4 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone-client<3.0.0) (6.0.2)
# Requirement already satisfied: loguru>=0.5.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone-client<3.0.0) (0.7.3)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone-client<3.0.0) (4.14.1)
# Requirement already satisfied: dnspython>=2.0.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone-client<3.0.0) (2.7.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone-client<3.0.0) (2.9.0.post0)
# Requirement already satisfied: urllib3>=1.21.1 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone-client<3.0.0) (2.5.0)
# Requirement already satisfied: tqdm>=4.64.1 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone-client<3.0.0) (4.67.1)
# Requirement already satisfied: numpy>=1.22.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone-client<3.0.0) (2.3.2)
# Requirement already satisfied: six>=1.5 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from python-dateutil>=2.5.3->pinecone-client<3.0.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from requests>=2.19.0->pinecone-client<3.0.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from requests>=2.19.0->pinecone-client<3.0.0) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from requests>=2.19.0->pinecone-client<3.0.0) (2025.7.14)
# Using cached pinecone_client-2.2.4-py3-none-any.whl (179 kB)
# Installing collected packages: pinecone-client
# Successfully installed pinecone-client-2.2.4

# %%
# !{sys.executable} -m pip show pinecone-client
# Out:
# Name: pinecone-client
# Version: 2.2.4
# Summary: Pinecone client and SDK
# Home-page: https://www.pinecone.io/
# Author: Pinecone Systems, Inc.
# Author-email: support@pinecone.io
# License: Proprietary License
# Location: /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages
# Requires: dnspython, loguru, numpy, python-dateutil, pyyaml, requests, tqdm, typing-extensions, urllib3
# Required-by:

# %%
# !{sys.executable} -m pip install 'protobuf<4.0.0'
# Out:
# Collecting protobuf<4.0.0
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# protoc-gen-openapiv2 0.0.1 requires protobuf>=4.21.0, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed protobuf-3.20.3

# %%
import sys
# !{sys.executable} -m pip install langchain langchain-community langchain-pinecone
# Out:
# Requirement already satisfied: langchain in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (0.3.27)
# Collecting langchain-community
#   Using cached langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-pinecone in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (0.2.11)
# Collecting pinecone-client[grpc]
#   Downloading pinecone_client-6.0.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: certifi>=2019.11.17 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone-client[grpc]) (2025.7.14)
# Requirement already satisfied: googleapis-common-protos>=1.66.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone-client[grpc]) (1.70.0)
# Requirement already satisfied: grpcio>=1.59.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone-client[grpc]) (1.74.0)
# Requirement already satisfied: lz4>=3.1.3 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone-client[grpc]) (4.4.4)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone-client[grpc]) (0.0.7)
# Requirement already satisfied: protobuf<6.0,>=5.29 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone-client[grpc]) (5.29.5)
# Requirement already satisfied: protoc-gen-openapiv2<0.0.2,>=0.0.1 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone-client[grpc]) (0.0.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone-client[grpc]) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone-client[grpc]) (4.14.1)
# Requirement already satisfied: urllib3>=1.26.5 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone-client[grpc]) (2.5.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain) (0.3.72)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain) (0.3.9)
# Requirement already satisfied: langsmith>=0.1.17 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain) (0.4.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: packaging>=23.2 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-community) (3.12.14)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-community) (2.3.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Collecting pinecone<8.0.0,>=6.0.0 (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone)
#   Using cached pinecone-7.3.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: langchain-tests<1.0.0,>=0.3.7 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-pinecone) (0.3.20)
# Requirement already satisfied: langchain-openai>=0.3.11 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-pinecone) (0.3.28)
# Requirement already satisfied: pytest<9,>=7 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (8.4.1)
# Requirement already satisfied: pytest-asyncio<1,>=0.20 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.26.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.28.1)
# Requirement already satisfied: syrupy<5,>=4 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (4.9.1)
# Requirement already satisfied: pytest-socket<1,>=0.6.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.7.0)
# Requirement already satisfied: pytest-benchmark in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (5.1.0)
# Requirement already satisfied: pytest-codspeed in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (4.0.0)
# Requirement already satisfied: pytest-recording in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.13.4)
# Requirement already satisfied: vcrpy>=7.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (7.0.0)
# Requirement already satisfied: anyio in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.16.0)
# Requirement already satisfied: pinecone-plugin-assistant<2.0.0,>=1.6.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.7.0)
# Requirement already satisfied: aiohttp-retry<3.0.0,>=2.9.1 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.1)
# Requirement already satisfied: iniconfig>=1 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (2.19.2)
# Requirement already satisfied: openai<2.0.0,>=1.86.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-openai>=0.3.11->langchain-pinecone) (1.92.3)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langchain-openai>=0.3.11->langchain-pinecone) (0.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai>=0.3.11->langchain-pinecone) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai>=0.3.11->langchain-pinecone) (0.10.0)
# Requirement already satisfied: sniffio in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai>=0.3.11->langchain-pinecone) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai>=0.3.11->langchain-pinecone) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-openai>=0.3.11->langchain-pinecone) (2024.11.6)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langsmith>=0.1.17->langchain) (3.11.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: six>=1.5 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from python-dateutil>=2.5.3->pinecone-client[grpc]) (1.17.0)
# Requirement already satisfied: wrapt in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from vcrpy>=7.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.17.2)
# Requirement already satisfied: py-cpuinfo in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pytest-benchmark->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (9.0.0)
# Requirement already satisfied: cffi>=1.17.1 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.17.1)
# Requirement already satisfied: rich>=13.8.1 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (14.1.0)
# Requirement already satisfied: pycparser in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from cffi>=1.17.1->pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (2.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from rich>=13.8.1->pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/kiranmulawad/AI-Funding/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.1->pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.1.2)
# Downloading pinecone_client-6.0.0-py3-none-any.whl (6.7 kB)
# Using cached langchain_community-0.3.27-py3-none-any.whl (2.5 MB)
# Using cached pinecone-7.3.0-py3-none-any.whl (587 kB)
# Installing collected packages: pinecone-client, pinecone, langchain-community
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [langchain-community]ngchain-community]
# Successfully installed langchain-community-0.3.27 pinecone-7.3.0 pinecone-client-6.0.0

# %%
# %% LangChain version of your query engine
import os
import re
import pandas as pd
from dotenv import load_dotenv
from datetime import datetime
from dateutil import parser

from langchain.vectorstores import Pinecone as LangPinecone
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.llms import Ollama
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.schema import Document
from pinecone import Pinecone

# %% Load .env
load_dotenv()
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
PINECONE_ENV = os.getenv("PINECONE_ENV", "gcp-starter")  # your pinecone environment
PINECONE_INDEX = "funding-search-bge"

# %% Setup embedding model
embedding_model = HuggingFaceEmbeddings(model_name="BAAI/bge-small-en")

# %% Connect to Pinecone (both LangChain + native)
pc = Pinecone(api_key=PINECONE_API_KEY)
index = LangPinecone.from_existing_index(index_name=PINECONE_INDEX, embedding=embedding_model)

# %% Query
user_query = "We are an AI company focused on AI for robotics. We are focusing on research right now."
user_location = "Rhineland-Palatinate"
funding_need = "200000"
target_domain = "AI"

# %% Get documents (metadata + vector matched)
retriever = index.as_retriever(search_kwargs={"k": 10})
docs = retriever.get_relevant_documents(user_query)

# %% Optional: custom scoring
def safe_parse_deadline(deadline_str):
    try:
        return parser.parse(deadline_str, dayfirst=True, fuzzy=True)
    except:
        return None

def compute_relevance_score(metadata):
    score = 0
    # Domain match
    if target_domain.lower() in str(metadata.get("domain", "")).lower():
        score += 0.4
    # Amount match
    try:
        amount_val = int(re.sub(r"[^\d]", "", str(metadata.get("amount", "0"))))
        if amount_val >= int(funding_need):
            score += 0.3
    except:
        pass
    # Deadline
    if "month" in str(metadata.get("deadline", "")).lower() or "2025" in str(metadata.get("deadline", "")):
        score += 0.2
    # Keyword match
    if any(word.lower() in str(metadata.get("description", "")).lower() for word in user_query.split()):
        score += 0.1
    # Location
    if user_location.lower() in str(metadata.get("location", "")).lower():
        score += 0.1
    return round(score * 100)

# %% Score and sort
scored_docs = []
for doc in docs:
    meta = doc.metadata
    meta["relevance_score"] = compute_relevance_score(meta)
    meta["days_left"] = (
        safe_parse_deadline(meta.get("deadline", "")) - datetime.now()
    ).days if meta.get("deadline") else None
    scored_docs.append(meta)

scored_df = pd.DataFrame(scored_docs)
scored_df = scored_df.sort_values("relevance_score", ascending=False)
top_matches = scored_df.head(5).to_dict("records")

# %% Format into GPT-readable blocks
def format_for_prompt(matches):
    blocks = []
    for i, meta in enumerate(matches, 1):
        block = f"""**{i}. {meta.get("name", "Unnamed")}**\n"""
        for field in ["description", "domain", "eligibility", "amount", "deadline", "procedure", "contact", "location", "source"]:
            val = meta.get(field)
            if val:
                if field == "deadline" and meta.get("days_left"):
                    val += f" (🕒 {int(meta['days_left'])} days left)"
                block += f"- **{field.capitalize()}**: {val}\n"
        if meta.get("url"):
            block += f"- **More info**: {meta['url']}\n"
        blocks.append(block)
    return "\n".join(blocks)

semantic_output = format_for_prompt(top_matches)

# %% Prepare LLM prompt
llm_prompt = f"""
The company described itself as:

"{user_query}"

Here are the top 5 most relevant public funding programs in Germany:

{semantic_output}

Now, write a concise and professional recommendation for the **top 2–3 most relevant** programs in this format:

1. <Program Name>  
Why it fits: <Reason>  
**Description**: <...>  
**Domain**: <...>  
**Eligibility**: <...>  
**Amount**: <...>  
**Deadline**: <...>  
**Location**: <...>  
**Contact**: <...>  
**Next Steps**:  
- Step 1: <...>  
- Step 2: <...>
"""

# %% LLM call (LLaMA via Ollama)
llm = Ollama(model="llama3.2")
response = llm.invoke(llm_prompt)

# %% Final Output
print("\n🧾 Recommendation:\n")
print(response)
